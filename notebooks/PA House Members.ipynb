# %%
import csv
import feedparser

# %%
# Replace with the URL of the RSS feed you want to parse
rss_feed_url = "https://www.palegis.us/house/rss/session/members" 

# Parse the RSS feed
feed = feedparser.parse(rss_feed_url)
# print(feed)
# output = open('pa_state_senate_data.csv', 'w')
# for entry in feed.entries:
#    output.write(f'{entry}')
#output.close()

# Accessing and iterating through feed entries (articles, items)
records = []

for entry in feed.entries:
    record = {}
    record['name'] = entry.get('title', 'N/A')
    record['link'] = entry.get('link', 'N/A')
    record['published'] = entry.get('published_parsed')
    record['id'] = entry.get('id')
    record['district'] = entry.get('parss_district')
    record['county'] = entry.get('parss_county')
    record['party'] = entry.get('parss_party')
    record['personal_history'] = entry.get('parss_personal_history')
    record['occupation'] = entry.get('parss_occupation')
    record['parents'] = entry.get('parss_parents')
    record['education'] = entry.get('parss_education')
    record['career'] = entry.get('parss_career')
    record['affiliations'] = entry.get('parss_other_boards_committees_commissions')
    record['military_service'] = entry.get('parss_military_service')
    record['district_1_street1'] = entry.get('parss_district_1_street1')
    record['district_1_street2'] = entry.get('parss_district_1_street2')
    record['district_1_citystatezip'] = entry.get('parss_district_1_citystatezip')
    record['district_1_phone'] = entry.get('parss_district_1_phone')
    record['district_2_street1'] = entry.get('parss_district_2_street1')
    record['district_2_street2'] = entry.get('parss_district_2_street2')
    record['district_2_citystatezip'] = entry.get('parss_district_2_citystatezip')
    record['district_2_phone'] = entry.get('parss_district_2_phone')
    record['district_3_street1'] = entry.get('parss_district_3_street1')
    record['district_3_street2'] = entry.get('parss_district_3_street2')
    record['district_3_citystatezip'] = entry.get('parss_district_3_citystatezip')
    record['district_3_phone'] = entry.get('parss_district_3_phone')
    record['capitol_street1'] = entry.get('parss_capitoladdress_street1')
    record['capitol_street2'] = entry.get('parss_capitoladdress_street2')
    record['capitol_citystatezip'] = entry.get('parss_capitoladdress_citystatezip')
    record['capitol_phone'] = entry.get('parss_capitoladdress_phone')
    record['image_src'] = entry.get('parss_imagesrc')
    record['member_elect'] = entry.get('parss_memberelect')
    record['member_vacant'] = entry.get('parss_vacant')
    records.append(record)
    
    #print(record)
    #print("-" * 20)

print(records)
# Out:
# [{'name': 'PATRICK J. HARKINS', 'link': 'https://www.legis.state.pa.us/cfdocs/legis/home/member_information/House_bio.cfm?id=1081', 'published': time.struct_time(tm_year=2025, tm_mon=1, tm_mday=7, tm_hour=13, tm_min=12, tm_sec=8, tm_wday=1, tm_yday=7, tm_isdst=0), 'id': 'House_1_20250107_011208', 'district': '001', 'county': 'Erie County (Part)', 'party': 'D', 'personal_history': '', 'occupation': 'Legislator', 'parents': '', 'education': 'Technical Memorial High School, 1982<br />Attended: Mercyhurst College<br />Attended: Penn State Behrend College', 'career': '', 'affiliations': '', 'military_service': '', 'district_1_street1': '460 East 26th Street', 'district_1_street2': '', 'district_1_citystatezip': 'Erie, PA 16504', 'district_1_phone': '(814) 459-1949', 'district_2_street1': '', 'district_2_street2': '', 'district_2_citystatezip': '', 'district_2_phone': '', 'district_3_street1': '', 'district_3_street2': '', 'district_3_citystatezip': '', 'district_3_phone': '', 'capitol_street1': '331 Irvis Office Building', 'capitol_street2': 'P.O. Box 202001', 'capitol_citystatezip': 'Harrisburg, PA 171202001', 'capitol_phone': '(717) 787-7406', 'image_src': 'https://www.palegis.us/resources/images/members/200/1081.jpg', 'member_elect': '', 'member_vacant': 'false'}, {'name': 'ROBERT E. MERSKI', 'link': 'https://www.legis.state.pa.us/cfdocs/legis/home/member_information/House_bio.cfm?id=1822', 'published': time.struct_time(tm_year=2025, tm_mon=1, tm_mday=7, tm_hour=13, tm_min=12, tm_sec=8, tm_wday=1, tm_yday=7, tm_isdst=0), 'id': 'House_2_20250107_011208', 'district': '002', 'county': 'Erie County (Part)', 'party': 'D', 'personal_history': 'Married to Emily M. Merski, Esq.', 'occupation': 'Educator', 'parents': '', 'education': 'Cathedral Preparatory School, Erie PA 1993<br />Mercyhurst University, Erie PA 1999 BA Education<br />Wilkes University, Wilkes Barre, PA MS Education', 'career': '', 'affiliations': '', 'military_service': '', 'district_1_street1': '3921 Buffalo Road', 'district_1_street2': '', 'district_1_citystatezip': 'Erie, PA 16510', 'district_1_phone': '(814) 455-6319', 'district_2_street1': '', 'district_2_street2': '', 'district_2_citystatezip': '', 'district_2_phone': '', 'district_3_street1': '', 'district_3_street2': '', 'district_3_citystatezip': '', 'district_3_phone': '', 'capitol_street1': '221 Irvis Office Building', 'capitol_street2': 'P.O. Box 202002', 'capitol_citystatezip': 'Harrisburg, PA 171202002', 'capitol_phone': '(717) 787-4358', 'image_src': 'https://www.palegis.us/resources/images/members/200/1822.jpg', 'member_elect': '', 'member_vacant': 'false'}, {'name': 'RYAN A. BIZZARRO', 'link': 'https://www.legis.state.pa.us/cfdocs/legis/home/member_information/House_bio.cfm?id=1619', 'published': time.struct_time(tm_year=2025, tm_mon=1, tm_mday=9, tm_hour=15, tm_min=5, tm_sec=44, tm_wday=3, tm_yday=9, tm_isdst=0), 'id': 'House_3_20250109_030544', 'district': '003', 'county': 'Erie County (Part)', 'party': 'D', 'personal_history': '', 'occupation': 'Business Development', 'parents': '', 'education': 'McDowell High School, 2004<br />Edinboro University of PA, A.A. Criminal Justice 2006 & B.A. Political Science, 2008<br />Gannon University, Masters Public Administration<br />', 'career': '', 'affiliations': '', 'military_service': '', 'district_1_street1': 'Peninsula Plaza', 'district_1_street2': '1101 Peninsula Drive', 'district_1_citystatezip': 'Erie, PA 16505', 'district_1_phone': '(814) 835-2880', 'district_2_street1': '', 'district_2_street2': '', 'district_2_citystatezip': '', 'district_2_phone': '', 'district_3_street1': '', 'district_3_street2': '', 'district_3_citystatezip': '', 'district_3_phone': '', 'capitol_street1': '116 Main Capitol Building', 'capitol_street2': 'P.O. Box 202003', 'capitol_citystatezip': 'Harrisburg, PA 171202003', 'capitol_phone': '(717) 772-2297', 'image_src': 'https://www.palegis.us/resources/images/members/200/1619.jpg', 'member_elect': '', 'member_vacant': 'false'}, {'n ...

# %%
with open('pa_house_members.csv', 'w', newline='\n') as csvfile:
    # Define fieldnames from the keys of the first dictionary
    fieldnames = records[0].keys()
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

    # Write the header row
    writer.writeheader()

    # Write all data rows from the list of dictionaries
    writer.writerows(records[1:])

print(f"Data written to {csvfile}")
# Out:
# Data written to <_io.TextIOWrapper name='pa_house_members.csv' mode='w' encoding='UTF-8'>
